# %% [markdown]
# Himani Parikh - 1322085
#
# CSCI 636 - Big Data Analytics
#
# Hands on 3.1 : WordCount - Grep Command

# %% [markdown]
# ***Question:***
#
# Download the text to Alice's Adventures in Wonderland from
# http://www.gutenberg.org/files/11/11-0.txt
# (If it redirects you to a page with a welcome popup, click on the "Plain Text UTF-
# 8" option on that page or just download the attachment below) and run
# wordcount on it. This can be done by using hadoop commands. How many times
# does the word Cheshire occur? (Do not include the word 'Cheshire with an
# apostrophe. The string -->'Cheshire<-- does not count)
#
# Hint: grep is in the same jar file as the wordcount.

# %% [markdown]
# *Step* 1: Installing Hadoop italicized text

# %%
#Download Hadoop installation package

# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz

#Use the tar command with the -x flag to extract, -z to uncompress,
#-v for verbose output, and -f to specify that we’re extracting from a file

# !tar -xzvf hadoop-3.3.6.tar.gz

#copying the hadoop file to user/local
# !cp -r hadoop-3.3.6/ /usr/local/

#To find the default Java path
# !readlink -f /usr/bin/java | sed "s:bin/java::"

#set java home variable
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"

#Running Hadoop
# !/usr/local/hadoop-3.3.6/bin/hadoop

# %%
# Access files in Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# example	MapReduce	programs
# !/usr/local/hadoop-3.3.6/bin/hadoop jar /usr/local/hadoop-3.3.6/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.6.jar
# Out:
# An example program must be given as the first argument.
# Valid program names are:
#   aggregatewordcount: An Aggregate based map/reduce program that counts the words in the input files.
#   aggregatewordhist: An Aggregate based map/reduce program that computes the histogram of the words in the input files.
#   bbp: A map/reduce program that uses Bailey-Borwein-Plouffe to compute exact digits of Pi.
#   dbcount: An example job that count the pageview counts from a database.
#   distbbp: A map/reduce program that uses a BBP-type formula to compute exact bits of Pi.
#   grep: A map/reduce program that counts the matches of a regex in the input.
#   join: A job that effects a join over sorted, equally partitioned datasets
#   multifilewc: A job that counts words from several files.
#   pentomino: A map/reduce tile laying program to find solutions to pentomino problems.
#   pi: A map/reduce program that estimates Pi using a quasi-Monte Carlo method.
# ...

# %%
# Wordcount	MapReduce	programs
# !/usr/local/hadoop-3.3.6/bin/hadoop jar /usr/local/hadoop-3.3.6/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.6.jar wordcount
# Out:
# Usage: wordcount <in> [<in>...] <out>

# %%
# Verify	input	file	exists
# !ls '/content/drive/My Drive/Colab Notebooks/BigDataColabHimani/Data/'
# Out:
# alice.txt  words2.txt  words.txt

# %%
# Run	WordGrep.
# !/usr/local/hadoop-3.3.6/bin/hadoop jar \
/usr/local/hadoop-3.3.6/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.6.jar \
grep \
'/content/drive/My Drive/Colab Notebooks/BigDataColabHimani/Data/alice.txt' \
'/content/drive/My Drive/Colab Notebooks/BigDataColabHimani/out_grep' \
"[^']Cheshire"
# Out:
# 2023-09-28 22:10:12,822 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2023-09-28 22:10:12,960 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2023-09-28 22:10:12,960 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2023-09-28 22:10:13,292 INFO input.FileInputFormat: Total input files to process : 1
# 2023-09-28 22:10:13,329 INFO mapreduce.JobSubmitter: number of splits:1
# 2023-09-28 22:10:13,709 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local237487604_0001
# 2023-09-28 22:10:13,709 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2023-09-28 22:10:13,942 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2023-09-28 22:10:13,943 INFO mapreduce.Job: Running job: job_local237487604_0001
# 2023-09-28 22:10:13,954 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# ...

# %%
# See	WordGrep	output	directory
# !ls '/content/drive/My Drive/Colab Notebooks/BigDataColabHimani/out_grep'
# Out:
# part-r-00000  _SUCCESS

# %%
# View the WordGrep results.
# !more '/content/drive/My Drive/Colab Notebooks/BigDataColabHimani/out_grep/part-r-00000'
# Out:
# 6	 Cheshire
# 1	“Cheshire

# %% [markdown]
# Himani Parikh - 1322085
#
# CSCI 636 - Big Data Analytics
#
# Hands on 3.2 : WordMedian

# %% [markdown]
# ***Question:***
#
# The set of example MapReduce applications includes wordmedian, which
# computes the median length of words in a text file. If you run wordmedian using
# words.txt (the Shakespeare text) as input, what is the median word length?
# Note that wordmedian prints the median length to the terminal at the end of the
# MapReduce job; the output file does not contain the median length.
#
# Hint: wordmedian is in the same jar file as the wordcount.

# %%
#Download Hadoop installation package

# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz

#Use the tar command with the -x flag to extract, -z to uncompress,
#-v for verbose output, and -f to specify that we’re extracting from a file

# !tar -xzvf hadoop-3.3.6.tar.gz

#copying the hadoop file to user/local
# !cp -r hadoop-3.3.6/ /usr/local/

#To find the default Java path
# !readlink -f /usr/bin/java | sed "s:bin/java::"

#set java home variable
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"

#Running Hadoop
# !/usr/local/hadoop-3.3.6/bin/hadoop

# %%
# Access files in Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Verify	input	file	exists
# !ls '/content/drive/My Drive/Colab Notebooks/BigDataColabHimani/Data/'
# Out:
# alice.txt  words2.txt  words.txt

# %%
# Run	WordMedian.
# !/usr/local/hadoop-3.3.6/bin/hadoop jar \
/usr/local/hadoop-3.3.6/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.6.jar \
wordmedian \
'/content/drive/My Drive/Colab Notebooks/BigDataColabHimani/Data/words.txt' \
'/content/drive/My Drive/Colab Notebooks/BigDataColabHimani/out_wordmedian'
# Out:
# 2023-09-22 14:14:45,418 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2023-09-22 14:14:45,598 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2023-09-22 14:14:45,598 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2023-09-22 14:14:45,864 INFO input.FileInputFormat: Total input files to process : 1
# 2023-09-22 14:14:45,912 INFO mapreduce.JobSubmitter: number of splits:1
# 2023-09-22 14:14:46,226 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1985272567_0001
# 2023-09-22 14:14:46,226 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2023-09-22 14:14:46,454 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2023-09-22 14:14:46,455 INFO mapreduce.Job: Running job: job_local1985272567_0001
# 2023-09-22 14:14:46,464 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# ...
